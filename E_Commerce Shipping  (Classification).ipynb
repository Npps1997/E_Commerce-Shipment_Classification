# %%
import pandas as pd

# %%
eCommerce = pd.read_csv('E-commerceDataset.csv')

# %%
eCommerce.head()
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
eCommerce.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
#Renaming the target
eCommerce.rename(columns={"Reached.on.Time_Y.N": "Reached_on_time"}, inplace= True)

# %%
eCommerce.describe(include='all')
# Out:
#                  ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# count   10999.00000           10999            10999         10999.000000
# unique          NaN               5                3                  NaN
# top             NaN               F             Ship                  NaN
# freq            NaN            3666             7462                  NaN
# mean     5500.00000             NaN              NaN             4.054459
# std      3175.28214             NaN              NaN             1.141490
# min         1.00000             NaN              NaN             2.000000
# 25%      2750.50000             NaN              NaN             3.000000
# 50%      5500.00000             NaN              NaN             4.000000
# 75%      8249.50000             NaN              NaN             5.000000
# max     10999.00000             NaN              NaN             7.000000
#
#         Customer_rating  Cost_of_the_Product  Prior_purchases  \
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
eCommerce.hist(bins= 50, figsize=(30,15))
# Out:
# array([[<AxesSubplot:title={'center':'ID'}>,
#         <AxesSubplot:title={'center':'Customer_care_calls'}>,
#         <AxesSubplot:title={'center':'Customer_rating'}>],
#        [<AxesSubplot:title={'center':'Cost_of_the_Product'}>,
#         <AxesSubplot:title={'center':'Prior_purchases'}>,
#         <AxesSubplot:title={'center':'Discount_offered'}>],
#        [<AxesSubplot:title={'center':'Weight_in_gms'}>,
#         <AxesSubplot:title={'center':'Reached_on_time'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
eCommerce.nunique()
# Out:
# ID                     10999
# Warehouse_block            5
# Mode_of_Shipment           3
# Customer_care_calls        6
# Customer_rating            5
# Cost_of_the_Product      215
# Prior_purchases            8
# Product_importance         3
# Gender                     2
# Discount_offered          65
# Weight_in_gms           4034
# Reached_on_time            2
# dtype: int64

# %%
plt.pie(eCommerce['Customer_rating'].unique(), labels=eCommerce['Warehouse_block'].unique(), radius=2)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b72d258dc0>,
# ...
#  [Text(2.0097999872652528, 0.8948206586733403, 'D'),
#   Text(-0.6798375443429163, 2.092324284928556, 'F'),
#   Text(-2.009799903486088, -0.8948208468443909, 'A'),
#   Text(-0.6798371035734416, -2.0923244281432254, 'B'),
#   Text(1.4720876452361211, -1.6349183358024868, 'C')])

# %%
eCommerce['Warehouse_block'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
eCommerce['Mode_of_Shipment'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
eCommerce['Product_importance'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
eCommerce['Gender'].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
eCommerce['Product_importance'].value_counts().plot(kind= 'pie', radius =2)
# Out:
# <AxesSubplot:ylabel='Product_importance'>

# %%
import seaborn as sns

# %%
plt.figure(figsize=(18, 18))

plt.subplot(3, 3, 1)
sns.countplot(x='Warehouse_block', hue='Reached_on_time', data=eCommerce)
plt.title('Warehouse Block', fontsize=15)

plt.subplot(3, 3, 2)
sns.countplot(x='Mode_of_Shipment', hue='Reached_on_time', data=eCommerce)
plt.title('Mode of Shipment', fontsize=15)

plt.subplot(3, 3, 3)
sns.countplot(x='Customer_care_calls', hue='Reached_on_time',  data=eCommerce)
plt.title('Customer Care Calls', fontsize=15)

plt.subplot(3, 3, 4)
sns.countplot(x='Customer_rating', hue='Reached_on_time',  data=eCommerce)
plt.title('Customer Rating', fontsize=15)

plt.subplot(3, 3, 5)
sns.countplot(x='Prior_purchases', hue='Reached_on_time',  data=eCommerce)
plt.title('Prior Purchases', fontsize=15)

plt.subplot(3, 3, 6)
sns.countplot(x='Product_importance', hue='Reached_on_time',  data=eCommerce)
plt.title('Product Importance', fontsize=15)

plt.subplot(3, 3, 7)
sns.countplot(x='Gender', hue='Reached_on_time',  data=eCommerce)
plt.title('Gender', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Gender')

# %%
plt.figure(figsize=(18, 18))

plt.subplot(3, 3, 7)
sns.countplot(x='Customer_rating', hue='Product_importance',  data=eCommerce)
# Out:
# <AxesSubplot:xlabel='Customer_rating', ylabel='count'>

# %% [markdown]
# # Correlation Matrix

# %%
corr_matrix= eCommerce.corr()
corr_matrix['Reached_on_time'].sort_values(ascending=False)
# Out:
# Reached_on_time        1.000000
# Discount_offered       0.397108
# Customer_rating        0.013119
# Prior_purchases       -0.055515
# Customer_care_calls   -0.067126
# Cost_of_the_Product   -0.073587
# Weight_in_gms         -0.268793
# ID                    -0.411822
# Name: Reached_on_time, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes= ['Reached_on_time','Discount_offered','Weight_in_gms','Cost_of_the_Product']
scatter_matrix(eCommerce[attributes], figsize=(30,15))
# Out:
# array([[<AxesSubplot:xlabel='Reached_on_time', ylabel='Reached_on_time'>,
#         <AxesSubplot:xlabel='Discount_offered', ylabel='Reached_on_time'>,
#         <AxesSubplot:xlabel='Weight_in_gms', ylabel='Reached_on_time'>,
#         <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Reached_on_time'>],
#        [<AxesSubplot:xlabel='Reached_on_time', ylabel='Discount_offered'>,
#         <AxesSubplot:xlabel='Discount_offered', ylabel='Discount_offered'>,
#         <AxesSubplot:xlabel='Weight_in_gms', ylabel='Discount_offered'>,
#         <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Discount_offered'>],
#        [<AxesSubplot:xlabel='Reached_on_time', ylabel='Weight_in_gms'>,
#         <AxesSubplot:xlabel='Discount_offered', ylabel='Weight_in_gms'>,
#         <AxesSubplot:xlabel='Weight_in_gms', ylabel='Weight_in_gms'>,
#         <AxesSubplot:xlabel='Cost_of_the_Product', ylabel='Weight_in_gms'>],
#        [<AxesSubplot:xlabel='Reached_on_time', ylabel='Cost_of_the_Product'>,
# ...

# %%
eCommerce.plot(kind= 'scatter', x= 'Weight_in_gms', y='Reached_on_time')
# Out:
# <AxesSubplot:xlabel='Weight_in_gms', ylabel='Reached_on_time'>

# %% [markdown]
# # Handling Categorial features

# %%
from sklearn.preprocessing import LabelEncoder
df_Ecom = eCommerce.apply(LabelEncoder().fit_transform)
df_Ecom.head()
# from sklearn.preprocessing import OneHotEncoder
# df_Ecom= pd.get_dummies(eCommerce,columns=['Warehouse_block','Mode_of_Shipment','Product_importance','Gender'],drop_first=False)
# df_Ecom.head()
# Out:
#    ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0   0                3                 0                    2
# 1   1                4                 0                    2
# 2   2                0                 0                    0
# 3   3                1                 0                    1
# 4   4                2                 0                    0
#
#    Customer_rating  Cost_of_the_Product  Prior_purchases  Product_importance  \
# 0                1                   81                1                   1
# 1                4                  120                0                   1
# 2                1                   87                2                   1
# 3                2                   80                2                   2
# 4                1                   88                1                   2
#
#    Gender  Discount_offered  Weight_in_gms  Reached_on_time
# 0       0                43            228                1
# ...

# %%
# target="Reached_on_time"
# y=df_Ecom[target].values
# df_Ecom.drop("Reached_on_time",axis=1,inplace=True)
# df_Ecom=pd.concat([df_Ecom,eCommerce[target]],axis=1)
# df_Ecom.head()

# %%
#Train test split
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df_Ecom, test_size=0.2, random_state=42)

# %%
train_set.shape, test_set.shape
# Out:
# ((8799, 12), (2200, 12))

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size= 0.2, random_state=42)
for train_index, test_index in split.split(df_Ecom, df_Ecom['Mode_of_Shipment'],df_Ecom['Customer_care_calls']):
    strat_trainSet = df_Ecom.loc[train_index]
    strat_testSet = df_Ecom.loc[test_index]

# %%
y_train= strat_trainSet['Reached_on_time']
x_train = strat_trainSet.drop("Reached_on_time", axis=1)

# %%
x_train.shape, y_train.shape
# Out:
# ((8799, 11), (8799,))

# %% [markdown]
# # Pipeline

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
my_pipeline= Pipeline([
    ('Imputer', SimpleImputer(strategy= 'median')),
    ('Std_scaler', StandardScaler())
])

# %%
Ecom_tr= my_pipeline.fit_transform(x_train)

# %%
Ecom_tr.shape
# Out:
# (8799, 11)

# %% [markdown]
# # Selection of Model

# %%
# from sklearn.tree import DecisionTreeClassifier
# model= DecisionTreeClassifier()
from sklearn.ensemble import RandomForestClassifier
model= RandomForestClassifier()
model.fit(Ecom_tr, y_train)
model.score(Ecom_tr, y_train)
# Out:
# 1.0

# %%
from sklearn.model_selection import cross_val_score
a= cross_val_score(model, Ecom_tr, y_train, cv= 3, scoring='accuracy')

# %%
print(a.mean())
# Out:
# 0.6684850551198999

# %%
from sklearn.model_selection import cross_val_predict
y_train_predict= cross_val_predict(model, Ecom_tr, y_train, cv= 3)

# %%
y_train_predict
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %% [markdown]
# # Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train, y_train_predict)
# Out:
# array([[2593,  926],
#        [1994, 3286]], dtype=int64)

# %% [markdown]
# # Precision, recall and f1 score

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
precision_score(y_train, y_train_predict)
# Out:
# 0.7801519468186134

# %%
recall_score(y_train, y_train_predict)
# Out:
# 0.6223484848484848

# %%
f1_score(y_train, y_train_predict)
# Out:
# 0.6923725242309312

# %% [markdown]
# # Precision Recall curve

# %%
from sklearn.metrics import precision_recall_curve

# %%
y_scores= cross_val_predict(model, Ecom_tr, y_train, cv=3)

# %%
y_scores
# Out:
# array([1, 1, 0, ..., 0, 1, 1], dtype=int64)

# %%
precisions, recalls, thresholds= precision_recall_curve(y_train, y_scores)

# %%
precisions
# Out:
# array([0.60006819, 0.78472554, 1.        ])

# %%
recalls
# Out:
# array([1.        , 0.62272727, 0.        ])

# %%
thresholds
# Out:
# array([0, 1], dtype=int64)

# %%
plt.plot(thresholds,precisions[:-1],'b--', label= "Precision")
plt.plot(thresholds,recalls[:-1],'g-', label= "Recall")
plt.xlabel('thresholds')
plt.legend(loc="upper left")
plt.ylim([0,1])
plt.show()
